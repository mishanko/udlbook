# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    # torch.nn.Linear(D_k, D_k),
    # torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
);


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
        nn.init.xavier_normal_(layer_in.weight)
        layer_in.bias.data.fill_(0.0) 


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.4)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=200, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.776151, train error 69.47,  test loss 1.785972, test error 71.00
# Epoch     1, train loss 1.589718, train error 62.40,  test loss 1.648485, test error 67.90
# Epoch     2, train loss 1.497279, train error 58.72,  test loss 1.573047, test error 64.60
# Epoch     3, train loss 1.357143, train error 49.17,  test loss 1.449171, test error 58.60
# Epoch     4, train loss 1.224642, train error 43.62,  test loss 1.341896, test error 53.00
# Epoch     5, train loss 1.134989, train error 40.67,  test loss 1.287926, test error 51.40
# Epoch     6, train loss 1.070795, train error 38.95,  test loss 1.244258, test error 50.90
# Epoch     7, train loss 1.004704, train error 35.88,  test loss 1.203944, test error 47.10
# Epoch     8, train loss 0.936320, train error 33.28,  test loss 1.181172, test error 48.10
# Epoch     9, train loss 0.876576, train error 31.25,  test loss 1.120672, test error 44.90
# Epoch    10, train loss 0.824447, train error 27.88,  test loss 1.077903, test error 42.50
# Epoch    11, train loss 0.807657, train error 27.82,  test loss 1.072307, test error 43.00
# Epoch    12, train loss 0.780246, train error 26.68,  test loss 1.071229, test error 44.00
# Epoch    13, train loss 0.752459, train error 25.03,  test loss 1.044053, test error 40.80
# Epoch    14, train loss 0.731766, train error 24.00,  test loss 1.037433, test error 41.40
# Epoch    15, train loss 0.710812, train error 23.62,  test loss 1.035162, test error 41.50
# Epoch    16, train loss 0.695165, train error 23.20,  test loss 1.032436, test error 39.60
# Epoch    17, train loss 0.681266, train error 22.40,  test loss 1.036500, test error 40.40
# Epoch    18, train loss 0.654553, train error 21.25,  test loss 1.015617, test error 39.90
# Epoch    19, train loss 0.642395, train error 20.65,  test loss 1.028489, test error 41.00
# Epoch    20, train loss 0.626055, train error 19.82,  test loss 1.012517, test error 40.20
# Epoch    21, train loss 0.620377, train error 20.07,  test loss 1.013035, test error 40.30
# Epoch    22, train loss 0.612470, train error 19.22,  test loss 1.013016, test error 40.00
# Epoch    23, train loss 0.607141, train error 19.15,  test loss 1.020177, test error 39.90
# Epoch    24, train loss 0.600216, train error 18.78,  test loss 1.009823, test error 39.80
# Epoch    25, train loss 0.591341, train error 18.47,  test loss 1.013022, test error 39.60
# Epoch    26, train loss 0.589973, train error 18.90,  test loss 1.016873, test error 39.90
# Epoch    27, train loss 0.580284, train error 18.22,  test loss 1.016709, test error 39.50
# Epoch    28, train loss 0.576643, train error 18.12,  test loss 1.019972, test error 39.50
# Epoch    29, train loss 0.567014, train error 17.45,  test loss 1.016283, test error 39.10
# Epoch    30, train loss 0.561028, train error 17.03,  test loss 1.010549, test error 39.30
# Epoch    31, train loss 0.558319, train error 16.78,  test loss 1.009535, test error 39.30
# Epoch    32, train loss 0.555610, train error 17.15,  test loss 1.006914, test error 38.90
# Epoch    33, train loss 0.553293, train error 16.85,  test loss 1.012084, test error 39.40
# Epoch    34, train loss 0.550576, train error 16.72,  test loss 1.010359, test error 38.80
# Epoch    35, train loss 0.548002, train error 16.60,  test loss 1.010363, test error 39.40
# Epoch    36, train loss 0.545368, train error 16.65,  test loss 1.011168, test error 39.20
# Epoch    37, train loss 0.542877, train error 16.47,  test loss 1.008587, test error 39.10
# Epoch    38, train loss 0.540933, train error 16.18,  test loss 1.012054, test error 38.80
# Epoch    39, train loss 0.538074, train error 16.40,  test loss 1.011116, test error 38.50
# Epoch    40, train loss 0.536508, train error 16.05,  test loss 1.011967, test error 39.00
# Epoch    41, train loss 0.535432, train error 15.90,  test loss 1.010782, test error 39.00
# Epoch    42, train loss 0.534422, train error 16.25,  test loss 1.011080, test error 39.10
# Epoch    43, train loss 0.533459, train error 16.00,  test loss 1.011389, test error 38.90
# Epoch    44, train loss 0.532400, train error 15.90,  test loss 1.010446, test error 39.10
# Epoch    45, train loss 0.531393, train error 16.05,  test loss 1.010916, test error 38.90
# Epoch    46, train loss 0.530456, train error 15.85,  test loss 1.010514, test error 39.10
# Epoch    47, train loss 0.529443, train error 15.88,  test loss 1.011670, test error 38.90
# Epoch    48, train loss 0.528378, train error 15.97,  test loss 1.010616, test error 38.90
# Epoch    49, train loss 0.527362, train error 15.68,  test loss 1.011803, test error 38.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
