# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!
from tqdm.notebook import tqdm
hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in tqdm(range(len(hidden_variables))):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304034, train error 89.93,  test loss 2.302323, test error 90.10
# Epoch   100, train loss 1.942525, train error 72.45,  test loss 1.805269, test error 70.53
# Epoch   200, train loss 1.911873, train error 71.43,  test loss 1.759641, test error 69.70
# Epoch   300, train loss 1.907135, train error 71.47,  test loss 1.754769, test error 69.65
# Epoch   400, train loss 1.907430, train error 71.55,  test loss 1.759393, test error 70.45
# Epoch   500, train loss 1.906356, train error 70.97,  test loss 1.755967, test error 69.60
# Epoch   600, train loss 1.902609, train error 71.18,  test loss 1.743580, test error 69.18
# Epoch   700, train loss 1.909562, train error 70.97,  test loss 1.767051, test error 69.88
# Epoch   800, train loss 1.903941, train error 70.32,  test loss 1.750913, test error 69.45
# Epoch   900, train loss 1.901536, train error 71.30,  test loss 1.737809, test error 70.20
# Training model with   4 hidden variables
# Epoch     0, train loss 2.243044, train error 82.32,  test loss 2.218987, test error 81.15
# Epoch   100, train loss 1.697652, train error 61.92,  test loss 1.494894, test error 58.08
# Epoch   200, train loss 1.674827, train error 61.60,  test loss 1.484725, test error 57.53
# Epoch   300, train loss 1.666891, train error 61.03,  test loss 1.482898, test error 57.30
# Epoch   400, train loss 1.668485, train error 61.83,  test loss 1.499681, test error 58.05
# Epoch   500, train loss 1.660698, train error 60.80,  test loss 1.494284, test error 57.15
# Epoch   600, train loss 1.661299, train error 61.60,  test loss 1.495953, test error 57.25
# Epoch   700, train loss 1.662360, train error 60.97,  test loss 1.502540, test error 57.67
# Epoch   800, train loss 1.660908, train error 61.20,  test loss 1.499132, test error 57.75
# Epoch   900, train loss 1.660625, train error 61.00,  test loss 1.493131, test error 58.17
# Training model with   6 hidden variables
# Epoch     0, train loss 2.279577, train error 90.05,  test loss 2.277969, test error 89.80
# Epoch   100, train loss 1.698989, train error 61.62,  test loss 1.521022, test error 59.22
# Epoch   200, train loss 1.660729, train error 59.58,  test loss 1.496585, test error 57.97
# Epoch   300, train loss 1.652477, train error 59.72,  test loss 1.497921, test error 58.30
# Epoch   400, train loss 1.642287, train error 58.70,  test loss 1.508702, test error 58.17
# Epoch   500, train loss 1.645673, train error 58.55,  test loss 1.504842, test error 58.38
# Epoch   600, train loss 1.637902, train error 58.83,  test loss 1.499299, test error 58.33
# Epoch   700, train loss 1.637932, train error 58.50,  test loss 1.487363, test error 57.55
# Epoch   800, train loss 1.635098, train error 58.55,  test loss 1.502065, test error 57.88
# Epoch   900, train loss 1.627777, train error 58.22,  test loss 1.485350, test error 56.55
# Training model with   8 hidden variables
# Epoch     0, train loss 2.219119, train error 81.78,  test loss 2.189415, test error 80.85
# Epoch   100, train loss 1.515845, train error 50.55,  test loss 1.320735, test error 49.25
# Epoch   200, train loss 1.488109, train error 50.60,  test loss 1.300005, test error 47.75
# Epoch   300, train loss 1.463057, train error 49.88,  test loss 1.297566, test error 47.17
# Epoch   400, train loss 1.446932, train error 48.85,  test loss 1.301823, test error 47.15
# Epoch   500, train loss 1.441453, train error 48.50,  test loss 1.300418, test error 47.33
# Epoch   600, train loss 1.438175, train error 48.62,  test loss 1.306723, test error 47.35
# Epoch   700, train loss 1.433433, train error 48.97,  test loss 1.310901, test error 48.15
# Epoch   800, train loss 1.439382, train error 50.03,  test loss 1.316025, test error 48.42
# Epoch   900, train loss 1.431870, train error 48.97,  test loss 1.320087, test error 47.92
# Training model with  10 hidden variables
# Epoch     0, train loss 2.282311, train error 87.70,  test loss 2.270143, test error 88.47
# Epoch   100, train loss 1.474247, train error 49.28,  test loss 1.303785, test error 47.88
# Epoch   200, train loss 1.408389, train error 47.28,  test loss 1.230869, test error 45.00
# Epoch   300, train loss 1.384623, train error 46.45,  test loss 1.230359, test error 45.33
# Epoch   400, train loss 1.371299, train error 45.90,  test loss 1.240833, test error 45.62
# Epoch   500, train loss 1.358859, train error 45.10,  test loss 1.237853, test error 45.10
# Epoch   600, train loss 1.354720, train error 45.35,  test loss 1.249162, test error 45.60
# Epoch   700, train loss 1.351604, train error 45.53,  test loss 1.247831, test error 45.25
# Epoch   800, train loss 1.343613, train error 45.28,  test loss 1.251465, test error 45.75
# Epoch   900, train loss 1.342836, train error 45.35,  test loss 1.259213, test error 45.97
# Training model with  14 hidden variables
# Epoch     0, train loss 2.157932, train error 82.35,  test loss 2.114910, test error 80.93
# Epoch   100, train loss 1.489005, train error 50.70,  test loss 1.406255, test error 54.03
# Epoch   200, train loss 1.408585, train error 48.58,  test loss 1.402350, test error 53.05
# Epoch   300, train loss 1.358178, train error 45.55,  test loss 1.416798, test error 53.00
# Epoch   400, train loss 1.338032, train error 45.70,  test loss 1.405911, test error 51.83
# Epoch   500, train loss 1.317638, train error 44.92,  test loss 1.417926, test error 52.40
# Epoch   600, train loss 1.305183, train error 44.88,  test loss 1.411499, test error 51.95
# Epoch   700, train loss 1.296494, train error 44.47,  test loss 1.415346, test error 51.53
# Epoch   800, train loss 1.292195, train error 44.53,  test loss 1.428947, test error 51.70
# Epoch   900, train loss 1.288318, train error 44.08,  test loss 1.442130, test error 52.28
# Training model with  18 hidden variables
# Epoch     0, train loss 2.167434, train error 81.57,  test loss 2.137373, test error 81.40
# Epoch   100, train loss 1.440459, train error 48.78,  test loss 1.454091, test error 55.65
# Epoch   200, train loss 1.325055, train error 45.08,  test loss 1.436700, test error 53.38
# Epoch   300, train loss 1.255015, train error 43.08,  test loss 1.462173, test error 52.67
# Epoch   400, train loss 1.213094, train error 41.40,  test loss 1.472228, test error 51.60
# Epoch   500, train loss 1.203959, train error 41.70,  test loss 1.525992, test error 52.58
# Epoch   600, train loss 1.182789, train error 40.70,  test loss 1.540194, test error 52.50
# Epoch   700, train loss 1.174101, train error 40.58,  test loss 1.573809, test error 52.97
# Epoch   800, train loss 1.157807, train error 39.67,  test loss 1.607901, test error 53.22
# Epoch   900, train loss 1.148368, train error 39.30,  test loss 1.629232, test error 53.72
# Training model with  22 hidden variables
# Epoch     0, train loss 2.151102, train error 80.10,  test loss 2.102060, test error 78.68
# Epoch   100, train loss 1.282122, train error 41.55,  test loss 1.320155, test error 49.33
# Epoch   200, train loss 1.159059, train error 38.00,  test loss 1.381881, test error 50.40
# Epoch   300, train loss 1.090125, train error 36.47,  test loss 1.442415, test error 50.58
# Epoch   400, train loss 1.055414, train error 35.82,  test loss 1.525215, test error 51.08
# Epoch   500, train loss 1.035034, train error 34.15,  test loss 1.583660, test error 52.03
# Epoch   600, train loss 1.008971, train error 33.97,  test loss 1.645281, test error 52.53
# Epoch   700, train loss 0.993728, train error 33.32,  test loss 1.679113, test error 51.45
# Epoch   800, train loss 1.011299, train error 34.65,  test loss 1.763878, test error 53.15
# Epoch   900, train loss 0.982401, train error 33.25,  test loss 1.797781, test error 53.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.166687, train error 80.18,  test loss 2.132178, test error 79.32
# Epoch   100, train loss 1.207912, train error 39.78,  test loss 1.318526, test error 49.78
# Epoch   200, train loss 1.069597, train error 35.22,  test loss 1.432612, test error 49.80
# Epoch   300, train loss 0.985557, train error 32.53,  test loss 1.533395, test error 50.80
# Epoch   400, train loss 0.937513, train error 31.12,  test loss 1.672008, test error 51.53
# Epoch   500, train loss 0.903307, train error 30.10,  test loss 1.781610, test error 52.58
# Epoch   600, train loss 0.883723, train error 29.10,  test loss 1.888763, test error 52.42
# Epoch   700, train loss 0.889419, train error 29.68,  test loss 2.000928, test error 54.12
# Epoch   800, train loss 0.855899, train error 28.55,  test loss 2.028719, test error 52.45
# Epoch   900, train loss 0.857854, train error 28.85,  test loss 2.138602, test error 53.80
# Training model with  30 hidden variables
# Epoch     0, train loss 2.139297, train error 79.10,  test loss 2.104671, test error 78.70
# Epoch   100, train loss 1.082522, train error 35.40,  test loss 1.317456, test error 47.30
# Epoch   200, train loss 0.936895, train error 30.22,  test loss 1.503153, test error 49.08
# Epoch   300, train loss 0.843739, train error 27.93,  test loss 1.672593, test error 51.85
# Epoch   400, train loss 0.798980, train error 26.55,  test loss 1.809668, test error 51.62
# Epoch   500, train loss 0.770405, train error 25.97,  test loss 1.964350, test error 53.25
# Epoch   600, train loss 0.726102, train error 23.70,  test loss 2.084159, test error 52.92
# Epoch   700, train loss 0.700153, train error 23.07,  test loss 2.216574, test error 53.50
# Epoch   800, train loss 0.692166, train error 23.30,  test loss 2.342215, test error 54.10
# Epoch   900, train loss 0.686524, train error 23.05,  test loss 2.491308, test error 55.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.127777, train error 79.80,  test loss 2.092762, test error 78.90
# Epoch   100, train loss 1.051464, train error 34.40,  test loss 1.369803, test error 50.20
# Epoch   200, train loss 0.818702, train error 25.97,  test loss 1.646648, test error 50.85
# Epoch   300, train loss 0.698535, train error 22.75,  test loss 1.956161, test error 53.10
# Epoch   400, train loss 0.608180, train error 19.95,  test loss 2.264505, test error 53.33
# Epoch   500, train loss 0.582926, train error 19.57,  test loss 2.632737, test error 54.35
# Epoch   600, train loss 0.539719, train error 18.20,  test loss 2.987043, test error 55.03
# Epoch   700, train loss 0.550927, train error 20.12,  test loss 3.298038, test error 56.72
# Epoch   800, train loss 0.493515, train error 16.65,  test loss 3.607574, test error 55.58
# Epoch   900, train loss 0.470607, train error 15.60,  test loss 3.838209, test error 55.83
# Training model with  40 hidden variables
# Epoch     0, train loss 2.120716, train error 78.50,  test loss 2.084872, test error 78.70
# Epoch   100, train loss 0.918698, train error 29.03,  test loss 1.489383, test error 50.65
# Epoch   200, train loss 0.638773, train error 20.35,  test loss 1.941396, test error 54.17
# Epoch   300, train loss 0.508535, train error 16.15,  test loss 2.534020, test error 55.65
# Epoch   400, train loss 0.384379, train error 12.20,  test loss 3.231966, test error 57.08
# Epoch   500, train loss 0.339326, train error 11.28,  test loss 3.946740, test error 57.42
# Epoch   600, train loss 0.316903, train error 10.35,  test loss 4.815362, test error 59.30
# Epoch   700, train loss 0.227910, train error 7.72,  test loss 5.434450, test error 57.55
# Epoch   800, train loss 0.224312, train error 8.25,  test loss 6.113734, test error 57.80
# Epoch   900, train loss 0.251588, train error 9.18,  test loss 6.829331, test error 58.30
# Training model with  45 hidden variables
# Epoch     0, train loss 2.083682, train error 78.32,  test loss 2.038138, test error 77.53
# Epoch   100, train loss 0.803944, train error 25.47,  test loss 1.516628, test error 50.78
# Epoch   200, train loss 0.466159, train error 14.70,  test loss 2.291684, test error 52.85
# Epoch   300, train loss 0.306381, train error 9.30,  test loss 3.397321, test error 54.78
# Epoch   400, train loss 0.213737, train error 6.88,  test loss 4.708393, test error 55.55
# Epoch   500, train loss 0.170937, train error 5.50,  test loss 5.905591, test error 56.28
# Epoch   600, train loss 0.025915, train error 0.05,  test loss 7.293474, test error 55.90
# Epoch   700, train loss 0.013789, train error 0.00,  test loss 8.224481, test error 56.03
# Epoch   800, train loss 0.009685, train error 0.00,  test loss 8.897183, test error 56.15
# Epoch   900, train loss 0.007205, train error 0.00,  test loss 9.427991, test error 56.10
# Training model with  50 hidden variables
# Epoch     0, train loss 2.092092, train error 76.72,  test loss 2.058192, test error 77.82
# Epoch   100, train loss 0.694636, train error 21.32,  test loss 1.563654, test error 49.65
# Epoch   200, train loss 0.326114, train error 8.93,  test loss 2.672300, test error 53.80
# Epoch   300, train loss 0.129027, train error 2.35,  test loss 4.277420, test error 55.60
# Epoch   400, train loss 0.026004, train error 0.00,  test loss 5.890913, test error 56.08
# Epoch   500, train loss 0.012731, train error 0.00,  test loss 6.810677, test error 56.40
# Epoch   600, train loss 0.008105, train error 0.00,  test loss 7.433027, test error 56.47
# Epoch   700, train loss 0.005918, train error 0.00,  test loss 7.896373, test error 56.47
# Epoch   800, train loss 0.004609, train error 0.00,  test loss 8.271799, test error 56.38
# Epoch   900, train loss 0.003706, train error 0.00,  test loss 8.590780, test error 56.65
# Training model with  55 hidden variables
# Epoch     0, train loss 2.097963, train error 78.45,  test loss 2.059870, test error 77.53
# Epoch   100, train loss 0.646535, train error 20.03,  test loss 1.646050, test error 52.47
# Epoch   200, train loss 0.222492, train error 5.53,  test loss 3.017322, test error 54.67
# Epoch   300, train loss 0.039743, train error 0.03,  test loss 4.690070, test error 55.38
# Epoch   400, train loss 0.014524, train error 0.00,  test loss 5.714001, test error 55.90
# Epoch   500, train loss 0.008523, train error 0.00,  test loss 6.332034, test error 56.30
# Epoch   600, train loss 0.005811, train error 0.00,  test loss 6.777651, test error 56.53
# Epoch   700, train loss 0.004377, train error 0.00,  test loss 7.121194, test error 56.50
# Epoch   800, train loss 0.003428, train error 0.00,  test loss 7.408217, test error 56.60
# Epoch   900, train loss 0.002831, train error 0.00,  test loss 7.649940, test error 56.58
# Training model with  60 hidden variables
# Epoch     0, train loss 2.038383, train error 75.78,  test loss 2.015007, test error 77.57
# Epoch   100, train loss 0.526212, train error 15.82,  test loss 1.753946, test error 50.67
# Epoch   200, train loss 0.110345, train error 1.18,  test loss 3.291360, test error 53.67
# Epoch   300, train loss 0.020821, train error 0.00,  test loss 4.662843, test error 54.05
# Epoch   400, train loss 0.009622, train error 0.00,  test loss 5.364950, test error 54.33
# Epoch   500, train loss 0.006094, train error 0.00,  test loss 5.814899, test error 54.45
# Epoch   600, train loss 0.004361, train error 0.00,  test loss 6.149391, test error 54.50
# Epoch   700, train loss 0.003343, train error 0.00,  test loss 6.418112, test error 54.53
# Epoch   800, train loss 0.002684, train error 0.00,  test loss 6.638787, test error 54.55
# Epoch   900, train loss 0.002230, train error 0.00,  test loss 6.828558, test error 54.45
# Training model with  70 hidden variables
# Epoch     0, train loss 2.051045, train error 76.57,  test loss 2.025921, test error 77.82
# Epoch   100, train loss 0.311765, train error 6.93,  test loss 1.967722, test error 51.30
# Epoch   200, train loss 0.029981, train error 0.00,  test loss 3.540446, test error 53.72
# Epoch   300, train loss 0.010440, train error 0.00,  test loss 4.272139, test error 53.88
# Epoch   400, train loss 0.005925, train error 0.00,  test loss 4.685255, test error 54.03
# Epoch   500, train loss 0.004012, train error 0.00,  test loss 4.976679, test error 54.00
# Epoch   600, train loss 0.002975, train error 0.00,  test loss 5.198474, test error 53.95
# Epoch   700, train loss 0.002341, train error 0.00,  test loss 5.384321, test error 54.20
# Epoch   800, train loss 0.001915, train error 0.00,  test loss 5.534218, test error 54.03
# Epoch   900, train loss 0.001611, train error 0.00,  test loss 5.666374, test error 54.08
# Training model with  80 hidden variables
# Epoch     0, train loss 2.003859, train error 74.20,  test loss 1.912706, test error 74.97
# Epoch   100, train loss 0.209772, train error 2.80,  test loss 2.073734, test error 49.95
# Epoch   200, train loss 0.019095, train error 0.00,  test loss 3.371549, test error 51.22
# Epoch   300, train loss 0.007942, train error 0.00,  test loss 3.901758, test error 51.85
# Epoch   400, train loss 0.004727, train error 0.00,  test loss 4.226689, test error 51.80
# Epoch   500, train loss 0.003290, train error 0.00,  test loss 4.456460, test error 51.90
# Epoch   600, train loss 0.002480, train error 0.00,  test loss 4.634736, test error 52.03
# Epoch   700, train loss 0.001969, train error 0.00,  test loss 4.782168, test error 52.03
# Epoch   800, train loss 0.001622, train error 0.00,  test loss 4.906454, test error 52.17
# Epoch   900, train loss 0.001372, train error 0.00,  test loss 5.013393, test error 52.20
# Training model with  90 hidden variables
# Epoch     0, train loss 2.010582, train error 74.60,  test loss 1.965080, test error 76.07
# Epoch   100, train loss 0.148740, train error 1.75,  test loss 2.298319, test error 51.33
# Epoch   200, train loss 0.014471, train error 0.00,  test loss 3.469547, test error 52.65
# Epoch   300, train loss 0.006434, train error 0.00,  test loss 3.912163, test error 52.78
# Epoch   400, train loss 0.003922, train error 0.00,  test loss 4.192402, test error 52.75
# Epoch   500, train loss 0.002763, train error 0.00,  test loss 4.392825, test error 52.62
# Epoch   600, train loss 0.002108, train error 0.00,  test loss 4.550537, test error 52.85
# Epoch   700, train loss 0.001685, train error 0.00,  test loss 4.678232, test error 52.88
# Epoch   800, train loss 0.001396, train error 0.00,  test loss 4.786311, test error 52.97
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.879796, test error 53.00
# Training model with 100 hidden variables
# Epoch     0, train loss 1.977831, train error 73.15,  test loss 1.908432, test error 73.50
# Epoch   100, train loss 0.093769, train error 0.28,  test loss 2.197586, test error 50.45
# Epoch   200, train loss 0.012122, train error 0.00,  test loss 3.070764, test error 50.97
# Epoch   300, train loss 0.005648, train error 0.00,  test loss 3.434772, test error 51.15
# Epoch   400, train loss 0.003523, train error 0.00,  test loss 3.664710, test error 51.10
# Epoch   500, train loss 0.002502, train error 0.00,  test loss 3.828280, test error 51.20
# Epoch   600, train loss 0.001917, train error 0.00,  test loss 3.959947, test error 51.25
# Epoch   700, train loss 0.001539, train error 0.00,  test loss 4.067016, test error 51.25
# Epoch   800, train loss 0.001278, train error 0.00,  test loss 4.156543, test error 51.22
# Epoch   900, train loss 0.001088, train error 0.00,  test loss 4.234781, test error 51.40
# Training model with 120 hidden variables
# Epoch     0, train loss 1.998331, train error 73.55,  test loss 1.938674, test error 74.20
# Epoch   100, train loss 0.051490, train error 0.00,  test loss 2.222451, test error 51.60
# Epoch   200, train loss 0.009438, train error 0.00,  test loss 2.859096, test error 52.12
# Epoch   300, train loss 0.004686, train error 0.00,  test loss 3.145404, test error 52.17
# Epoch   400, train loss 0.002996, train error 0.00,  test loss 3.329545, test error 52.30
# Epoch   500, train loss 0.002163, train error 0.00,  test loss 3.465651, test error 52.33
# Epoch   600, train loss 0.001671, train error 0.00,  test loss 3.570017, test error 52.25
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.658937, test error 52.10
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.733850, test error 52.12
# Epoch   900, train loss 0.000964, train error 0.00,  test loss 3.800012, test error 52.25
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952773, train error 71.05,  test loss 1.895659, test error 72.70
# Epoch   100, train loss 0.036797, train error 0.00,  test loss 2.171096, test error 49.15
# Epoch   200, train loss 0.008189, train error 0.00,  test loss 2.666444, test error 49.22
# Epoch   300, train loss 0.004187, train error 0.00,  test loss 2.900286, test error 49.17
# Epoch   400, train loss 0.002720, train error 0.00,  test loss 3.054144, test error 49.05
# Epoch   500, train loss 0.001979, train error 0.00,  test loss 3.168631, test error 49.15
# Epoch   600, train loss 0.001538, train error 0.00,  test loss 3.258897, test error 49.12
# Epoch   700, train loss 0.001248, train error 0.00,  test loss 3.335111, test error 49.17
# Epoch   800, train loss 0.001045, train error 0.00,  test loss 3.399459, test error 49.28
# Epoch   900, train loss 0.000896, train error 0.00,  test loss 3.456439, test error 49.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.957238, train error 72.35,  test loss 1.875369, test error 71.97
# Epoch   100, train loss 0.029324, train error 0.00,  test loss 2.006243, test error 47.38
# Epoch   200, train loss 0.007178, train error 0.00,  test loss 2.385711, test error 47.47
# Epoch   300, train loss 0.003773, train error 0.00,  test loss 2.570653, test error 47.38
# Epoch   400, train loss 0.002478, train error 0.00,  test loss 2.693235, test error 47.45
# Epoch   500, train loss 0.001814, train error 0.00,  test loss 2.786235, test error 47.50
# Epoch   600, train loss 0.001417, train error 0.00,  test loss 2.860328, test error 47.60
# Epoch   700, train loss 0.001153, train error 0.00,  test loss 2.921381, test error 47.67
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 2.974425, test error 47.75
# Epoch   900, train loss 0.000830, train error 0.00,  test loss 3.019721, test error 47.58
# Training model with 180 hidden variables
# Epoch     0, train loss 1.964033, train error 71.57,  test loss 1.910778, test error 72.93
# Epoch   100, train loss 0.024298, train error 0.00,  test loss 2.100539, test error 48.83
# Epoch   200, train loss 0.006531, train error 0.00,  test loss 2.471510, test error 48.55
# Epoch   300, train loss 0.003490, train error 0.00,  test loss 2.654777, test error 48.58
# Epoch   400, train loss 0.002316, train error 0.00,  test loss 2.778735, test error 48.62
# Epoch   500, train loss 0.001703, train error 0.00,  test loss 2.871553, test error 48.70
# Epoch   600, train loss 0.001334, train error 0.00,  test loss 2.945961, test error 48.65
# Epoch   700, train loss 0.001089, train error 0.00,  test loss 3.007647, test error 48.65
# Epoch   800, train loss 0.000916, train error 0.00,  test loss 3.061696, test error 48.60
# Epoch   900, train loss 0.000788, train error 0.00,  test loss 3.108483, test error 48.65
# Training model with 200 hidden variables
# Epoch     0, train loss 1.903255, train error 70.00,  test loss 1.827936, test error 70.93
# Epoch   100, train loss 0.021509, train error 0.00,  test loss 1.930605, test error 46.65
# Epoch   200, train loss 0.006146, train error 0.00,  test loss 2.223634, test error 46.58
# Epoch   300, train loss 0.003327, train error 0.00,  test loss 2.372807, test error 46.62
# Epoch   400, train loss 0.002217, train error 0.00,  test loss 2.474620, test error 46.70
# Epoch   500, train loss 0.001637, train error 0.00,  test loss 2.550934, test error 46.65
# Epoch   600, train loss 0.001284, train error 0.00,  test loss 2.612409, test error 46.62
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.664615, test error 46.58
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.708380, test error 46.62
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.747360, test error 46.72
# Training model with 250 hidden variables
# Epoch     0, train loss 1.882643, train error 68.97,  test loss 1.808926, test error 70.85
# Epoch   100, train loss 0.016912, train error 0.00,  test loss 1.857468, test error 46.92
# Epoch   200, train loss 0.005339, train error 0.00,  test loss 2.101542, test error 46.95
# Epoch   300, train loss 0.002976, train error 0.00,  test loss 2.227421, test error 46.67
# Epoch   400, train loss 0.002012, train error 0.00,  test loss 2.314808, test error 46.67
# Epoch   500, train loss 0.001499, train error 0.00,  test loss 2.380601, test error 46.58
# Epoch   600, train loss 0.001183, train error 0.00,  test loss 2.433806, test error 46.60
# Epoch   700, train loss 0.000972, train error 0.00,  test loss 2.478848, test error 46.58
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.517061, test error 46.55
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.550655, test error 46.55
# Training model with 300 hidden variables
# Epoch     0, train loss 1.893385, train error 68.25,  test loss 1.829651, test error 71.22
# Epoch   100, train loss 0.014387, train error 0.00,  test loss 1.893295, test error 47.42
# Epoch   200, train loss 0.004819, train error 0.00,  test loss 2.120038, test error 47.60
# Epoch   300, train loss 0.002725, train error 0.00,  test loss 2.240651, test error 47.62
# Epoch   400, train loss 0.001854, train error 0.00,  test loss 2.324379, test error 47.62
# Epoch   500, train loss 0.001388, train error 0.00,  test loss 2.388031, test error 47.58
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.438618, test error 47.47
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.482262, test error 47.60
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.519235, test error 47.55
# Epoch   900, train loss 0.000661, train error 0.00,  test loss 2.551474, test error 47.62
# Training model with 400 hidden variables
# Epoch     0, train loss 1.851914, train error 67.90,  test loss 1.794778, test error 70.00
# Epoch   100, train loss 0.011742, train error 0.00,  test loss 1.759557, test error 46.40
# Epoch   200, train loss 0.004191, train error 0.00,  test loss 1.932425, test error 46.12
# Epoch   300, train loss 0.002425, train error 0.00,  test loss 2.029106, test error 46.00
# Epoch   400, train loss 0.001669, train error 0.00,  test loss 2.096614, test error 46.08
# Epoch   500, train loss 0.001257, train error 0.00,  test loss 2.148245, test error 46.10
# Epoch   600, train loss 0.001001, train error 0.00,  test loss 2.190090, test error 46.10
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.225100, test error 46.00
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.255658, test error 46.03
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.282727, test error 46.10

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
