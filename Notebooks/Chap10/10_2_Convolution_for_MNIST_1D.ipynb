# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='../Chap08/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ../Chap08/mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']

# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 4000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
    nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding='valid'),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(in_features=60, out_features=D_o)
)

# %%
# He initialization of weights
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()

# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)

# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)

# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100

# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
    # loop over batches
    for i, data in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = data
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch[:,None,:])
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train[:,None,:])
    pred_val = model(x_val[:,None,:])
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_val_class = torch.max(pred_val.data, 1)
    errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
    losses_train[epoch] = loss_function(pred_train, y_train).item()
    losses_val[epoch]= loss_function(pred_val, y_val).item()
    print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

    # tell scheduler to consider updating learning rate
    scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.018300, train error 78.88,  val loss 2.022326, percent error 80.00
# Epoch     1, train loss 1.596506, train error 63.45,  val loss 1.609628, percent error 62.80
# Epoch     2, train loss 1.389487, train error 56.70,  val loss 1.410581, percent error 57.83
# Epoch     3, train loss 1.336781, train error 55.00,  val loss 1.364540, percent error 56.42
# Epoch     4, train loss 1.226779, train error 51.15,  val loss 1.260754, percent error 53.00
# Epoch     5, train loss 1.100722, train error 45.30,  val loss 1.130149, percent error 46.60
# Epoch     6, train loss 1.105597, train error 46.12,  val loss 1.137561, percent error 49.53
# Epoch     7, train loss 0.937983, train error 37.83,  val loss 0.978810, percent error 39.10
# Epoch     8, train loss 0.815655, train error 31.90,  val loss 0.852535, percent error 33.88
# Epoch     9, train loss 0.688890, train error 26.72,  val loss 0.737638, percent error 28.60
# Epoch    10, train loss 0.607980, train error 24.07,  val loss 0.672423, percent error 26.65
# Epoch    11, train loss 0.529219, train error 21.45,  val loss 0.591625, percent error 23.60
# Epoch    12, train loss 0.494241, train error 19.85,  val loss 0.557543, percent error 22.93
# Epoch    13, train loss 0.523315, train error 20.35,  val loss 0.607428, percent error 22.68
# Epoch    14, train loss 0.459718, train error 18.22,  val loss 0.526822, percent error 21.22
# Epoch    15, train loss 0.395835, train error 14.43,  val loss 0.472263, percent error 17.75
# Epoch    16, train loss 0.392086, train error 14.90,  val loss 0.480466, percent error 17.90
# Epoch    17, train loss 0.324630, train error 12.20,  val loss 0.432460, percent error 16.30
# Epoch    18, train loss 0.315529, train error 11.85,  val loss 0.422813, percent error 15.53
# Epoch    19, train loss 0.303451, train error 11.40,  val loss 0.452934, percent error 16.85
# Epoch    20, train loss 0.248737, train error 9.62,  val loss 0.389049, percent error 13.62
# Epoch    21, train loss 0.226623, train error 8.47,  val loss 0.383389, percent error 13.50
# Epoch    22, train loss 0.199217, train error 6.55,  val loss 0.354781, percent error 11.75
# Epoch    23, train loss 0.200659, train error 7.25,  val loss 0.380573, percent error 12.82
# Epoch    24, train loss 0.187878, train error 6.65,  val loss 0.369608, percent error 12.30
# Epoch    25, train loss 0.184257, train error 6.82,  val loss 0.359065, percent error 12.22
# Epoch    26, train loss 0.182660, train error 6.50,  val loss 0.371902, percent error 12.60
# Epoch    27, train loss 0.168824, train error 5.65,  val loss 0.362709, percent error 12.15
# Epoch    28, train loss 0.192771, train error 7.20,  val loss 0.406618, percent error 13.85
# Epoch    29, train loss 0.161023, train error 5.53,  val loss 0.358140, percent error 11.45
# Epoch    30, train loss 0.129920, train error 4.32,  val loss 0.344799, percent error 11.05
# Epoch    31, train loss 0.148087, train error 5.32,  val loss 0.370075, percent error 12.22
# Epoch    32, train loss 0.130476, train error 4.45,  val loss 0.347868, percent error 11.10
# Epoch    33, train loss 0.111239, train error 3.53,  val loss 0.340103, percent error 10.62
# Epoch    34, train loss 0.117604, train error 3.93,  val loss 0.352807, percent error 10.68
# Epoch    35, train loss 0.109096, train error 3.55,  val loss 0.344694, percent error 10.43
# Epoch    36, train loss 0.127708, train error 4.35,  val loss 0.388715, percent error 12.22
# Epoch    37, train loss 0.101185, train error 3.18,  val loss 0.334372, percent error 9.72
# Epoch    38, train loss 0.105559, train error 3.68,  val loss 0.376118, percent error 11.18
# Epoch    39, train loss 0.090424, train error 2.75,  val loss 0.364908, percent error 11.00
# Epoch    40, train loss 0.073362, train error 1.90,  val loss 0.345523, percent error 9.88
# Epoch    41, train loss 0.069575, train error 1.62,  val loss 0.342785, percent error 9.80
# Epoch    42, train loss 0.069932, train error 1.72,  val loss 0.356943, percent error 10.03
# Epoch    43, train loss 0.064971, train error 1.68,  val loss 0.350843, percent error 9.97
# Epoch    44, train loss 0.066492, train error 1.65,  val loss 0.358881, percent error 10.22
# Epoch    45, train loss 0.065596, train error 1.55,  val loss 0.352005, percent error 10.07
# Epoch    46, train loss 0.068436, train error 2.03,  val loss 0.360061, percent error 10.22
# Epoch    47, train loss 0.063650, train error 1.70,  val loss 0.357590, percent error 10.10
# Epoch    48, train loss 0.058060, train error 1.40,  val loss 0.367741, percent error 10.07
# Epoch    49, train loss 0.066753, train error 1.82,  val loss 0.366526, percent error 10.20
# Epoch    50, train loss 0.055435, train error 1.07,  val loss 0.360225, percent error 9.65
# Epoch    51, train loss 0.058422, train error 1.57,  val loss 0.366787, percent error 10.00
# Epoch    52, train loss 0.065952, train error 1.95,  val loss 0.368711, percent error 9.95
# Epoch    53, train loss 0.070276, train error 2.15,  val loss 0.398244, percent error 10.80
# Epoch    54, train loss 0.051037, train error 1.05,  val loss 0.373024, percent error 9.85
# Epoch    55, train loss 0.050559, train error 1.00,  val loss 0.371008, percent error 10.03
# Epoch    56, train loss 0.051946, train error 1.32,  val loss 0.371162, percent error 9.75
# Epoch    57, train loss 0.054044, train error 1.22,  val loss 0.396928, percent error 10.00
# Epoch    58, train loss 0.046223, train error 1.03,  val loss 0.371330, percent error 9.97
# Epoch    59, train loss 0.045184, train error 0.90,  val loss 0.380954, percent error 9.80
# Epoch    60, train loss 0.041214, train error 0.70,  val loss 0.374718, percent error 9.43
# Epoch    61, train loss 0.039651, train error 0.60,  val loss 0.379579, percent error 9.57
# Epoch    62, train loss 0.039466, train error 0.55,  val loss 0.381197, percent error 9.65
# Epoch    63, train loss 0.039171, train error 0.57,  val loss 0.386785, percent error 9.78
# Epoch    64, train loss 0.038446, train error 0.62,  val loss 0.386582, percent error 9.72
# Epoch    65, train loss 0.039356, train error 0.57,  val loss 0.387451, percent error 9.68
# Epoch    66, train loss 0.037183, train error 0.57,  val loss 0.384754, percent error 9.75
# Epoch    67, train loss 0.037374, train error 0.55,  val loss 0.386124, percent error 9.60
# Epoch    68, train loss 0.037151, train error 0.50,  val loss 0.390214, percent error 9.82
# Epoch    69, train loss 0.036291, train error 0.57,  val loss 0.388054, percent error 9.75
# Epoch    70, train loss 0.035555, train error 0.57,  val loss 0.390216, percent error 9.82
# Epoch    71, train loss 0.035075, train error 0.53,  val loss 0.391305, percent error 9.53
# Epoch    72, train loss 0.034607, train error 0.50,  val loss 0.392143, percent error 9.90
# Epoch    73, train loss 0.034488, train error 0.50,  val loss 0.398079, percent error 9.72
# Epoch    74, train loss 0.033352, train error 0.47,  val loss 0.395687, percent error 9.72
# Epoch    75, train loss 0.033335, train error 0.50,  val loss 0.396030, percent error 9.68
# Epoch    76, train loss 0.033192, train error 0.47,  val loss 0.398410, percent error 9.57
# Epoch    77, train loss 0.033572, train error 0.50,  val loss 0.399463, percent error 9.75
# Epoch    78, train loss 0.034237, train error 0.53,  val loss 0.403816, percent error 9.90
# Epoch    79, train loss 0.031953, train error 0.50,  val loss 0.402455, percent error 9.53
# Epoch    80, train loss 0.030643, train error 0.45,  val loss 0.400838, percent error 9.57
# Epoch    81, train loss 0.030885, train error 0.43,  val loss 0.404793, percent error 9.70
# Epoch    82, train loss 0.030272, train error 0.40,  val loss 0.402430, percent error 9.57
# Epoch    83, train loss 0.030114, train error 0.40,  val loss 0.404068, percent error 9.60
# Epoch    84, train loss 0.030197, train error 0.43,  val loss 0.405239, percent error 9.85
# Epoch    85, train loss 0.029946, train error 0.38,  val loss 0.405210, percent error 9.72
# Epoch    86, train loss 0.029540, train error 0.40,  val loss 0.404714, percent error 9.60
# Epoch    87, train loss 0.029449, train error 0.32,  val loss 0.408136, percent error 9.68
# Epoch    88, train loss 0.029249, train error 0.32,  val loss 0.406061, percent error 9.82
# Epoch    89, train loss 0.029837, train error 0.38,  val loss 0.409439, percent error 9.68
# Epoch    90, train loss 0.028865, train error 0.32,  val loss 0.406710, percent error 9.68
# Epoch    91, train loss 0.029375, train error 0.43,  val loss 0.411174, percent error 10.00
# Epoch    92, train loss 0.028576, train error 0.32,  val loss 0.407917, percent error 9.65
# Epoch    93, train loss 0.028589, train error 0.40,  val loss 0.411210, percent error 9.53
# Epoch    94, train loss 0.028317, train error 0.43,  val loss 0.411380, percent error 9.72
# Epoch    95, train loss 0.028179, train error 0.28,  val loss 0.409305, percent error 9.68
# Epoch    96, train loss 0.027767, train error 0.30,  val loss 0.410942, percent error 9.65
# Epoch    97, train loss 0.027855, train error 0.38,  val loss 0.413902, percent error 9.70
# Epoch    98, train loss 0.027396, train error 0.32,  val loss 0.413387, percent error 9.78
# Epoch    99, train loss 0.027901, train error 0.28,  val loss 0.411848, percent error 9.82
